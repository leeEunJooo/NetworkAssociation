# %%
import numpy as np
from scipy.stats import norm
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.simplefilter('ignore')
import pandas as pd

# %%
data = pd.read_csv('data/new_client_data.csv', header=[0,1], index_col=0)

# %%
data.head(2)
# Out:
#   l1               AP               AP.1                             AP.2  \
# 0 l2       IP Address        MAC Address                     Map Location
# 1  0  164.125.168.230  84:3d:c6:e6:51:20  Pusan > GunSul (401) > GunSul1F
# 2  1  164.125.168.230  84:3d:c6:e6:51:20  Pusan > GunSul (401) > GunSul1F
#
#            AP.3 Association Time Association Time.1 Association Time.2  \
# 0          Name              day               hour             minute
# 1  16AP-401-1-1               30                 18                  2
# 2  16AP-401-1-1               29                 12                 16
#
#   Association Time.3 Association Time.4  ... Session Duration.3  \
# 0              month             second  ...            seconds
# 1                  7                  1  ...                  1
# 2                  7                 31  ...                  1
#
#                      Utilization  Utilization.1 Utilization.2 Utilization.3  \
# 0 Avg. Session Throughput (Kbps) Bytes Received    Bytes Sent  Data Retries
# 1                           <0.1              0             0             0
# 2                           <0.1              0             0             0
#
#      Utilization.4 Utilization.5 Utilization.6 Utilization.7 Utilization.8
# 0 Packets Received  Packets Sent    RSSI (dBm)   RTS Retries      SNR (dB)
# 1                0             0           -78             0            17
# 2                0             0          -128             0             0
#
# [2 rows x 43 columns]

# %%
lib = data['AP.2']['Map Location'].str.contains('Lib')

# %%
data[lib]['AP.2']['Map Location'].value_counts()
# Out:
# Pusan > Lib-2 (420) > Lib-2-2F              96383
# Pusan > Lib-2 (420) > Lib-2-3F              61767
# Pusan > YounGu-Lib (510) > YounGu-Lib-4F    56125
# Pusan > YounGu-Lib (510) > YounGu-Lib-1F    36858
# Pusan > Lib-2 (420) > Lib-2-1F              31976
# Pusan > YounGu-Lib (510) > YounGu-Lib-3F    23649
# YangSan > Med-Lib > Med-lib_2F              19892
# Pusan > YounGu-Lib (510) > YounGu-Lib-2F    15677
# YangSan > Med-Lib > Med-lib_1F              13071
# YangSan > Med-Lib > Med-lib_4F               3760
# YangSan > Med-Lib > Med-lib_3F               1738
# Name: Map Location, dtype: int64

# %%
set(data[lib]['AP.2']['Map Location'])
# Out:
# {'Pusan > Lib-2 (420) > Lib-2-1F',
#  'Pusan > Lib-2 (420) > Lib-2-2F',
#  'Pusan > Lib-2 (420) > Lib-2-3F',
#  'Pusan > YounGu-Lib (510) > YounGu-Lib-1F',
#  'Pusan > YounGu-Lib (510) > YounGu-Lib-2F',
#  'Pusan > YounGu-Lib (510) > YounGu-Lib-3F',
#  'Pusan > YounGu-Lib (510) > YounGu-Lib-4F',
#  'YangSan > Med-Lib > Med-lib_1F',
#  'YangSan > Med-Lib > Med-lib_2F',
#  'YangSan > Med-Lib > Med-lib_3F',
#  'YangSan > Med-Lib > Med-lib_4F'}

# %%
YounGu_Lib = data['AP.2']['Map Location'].str.contains('(510)')
Lib_2 = data['AP.2']['Map Location'].str.contains('(420)')

# %%
YounGu_Lib_df = data[YounGu_Lib]
Lib_2_df = data[Lib_2]

# %%
Lib_2_df.head()
# Out:
#               l1              AP               AP.1  \
# 0             l2      IP Address        MAC Address
# 6382081  6382080  172.20.140.111  44:e4:d9:40:b8:10
# 6382082  6382081  172.20.140.111  44:e4:d9:40:b8:10
# 6382083  6382082  172.20.140.111  44:e4:d9:40:b8:10
# 6382084  6382083  172.20.140.111  44:e4:d9:40:b8:10
# 6382085  6382084  172.20.140.111  44:e4:d9:40:b8:10
#
#                                    AP.2         AP.3 Association Time  \
# 0                          Map Location         Name              day
# 6382081  Pusan > Lib-2 (420) > Lib-2-1F  11S-420-1-1               13
# 6382082  Pusan > Lib-2 (420) > Lib-2-1F  11S-420-1-1               13
# 6382083  Pusan > Lib-2 (420) > Lib-2-1F  11S-420-1-1               13
# 6382084  Pusan > Lib-2 (420) > Lib-2-1F  11S-420-1-1               13
# 6382085  Pusan > Lib-2 (420) > Lib-2-1F  11S-420-1-1               13
#
#         Association Time.1 Association Time.2 Association Time.3  \
# 0                     hour             minute              month
# 6382081                  8                 41                  4
# 6382082                  8                 21                  4
# 6382083                 12                  2                  4
# 6382084                 14                  2                  4
# 6382085                 14                 22                  4
#
#         Association Time.4  ... Session Duration.3  \
# 0                   second  ...            seconds
# 6382081                  9  ...                 26
# 6382082                  3  ...                  5
# 6382083                  7  ...                 32
# 6382084                 42  ...                  5
# 6382085                 48  ...                 59
#
#                            Utilization  Utilization.1 Utilization.2  \
# 0       Avg. Session Throughput (Kbps) Bytes Received    Bytes Sent
# 6382081                            1.4         194072        728687
# 6382082                            1.1         117108         54766
# 6382083                           40.0       30835524       2366502
# 6382084                            0.8          70997         52173
# 6382085                            4.8        6623734        759365
#
#         Utilization.3    Utilization.4 Utilization.5 Utilization.6  \
# 0        Data Retries Packets Received  Packets Sent    RSSI (dBm)
# 6382081           219              802          1051           -61
# 6382082            38              194           175           -45
# 6382083          6553            25513         16043           -78
# 6382084          9048              229           256           -55
# 6382085          9238             6785          4755           -67
#
#         Utilization.7 Utilization.8
# 0         RTS Retries      SNR (dB)
# 6382081             0            32
# 6382082             0            47
# 6382083             0            15
# 6382084             0            40
# 6382085             0            23
#
# [5 rows x 43 columns]

# %%
Lib_2_df.columns
# Out:
# MultiIndex([(                   'l1',                             'l2'),
#             (                   'AP',                     'IP Address'),
#             (                 'AP.1',                    'MAC Address'),
#             (                 'AP.2',                   'Map Location'),
#             (                 'AP.3',                           'Name'),
#             (     'Association Time',                            'day'),
#             (   'Association Time.1',                           'hour'),
#             (   'Association Time.2',                         'minute'),
#             (   'Association Time.3',                          'month'),
#             (   'Association Time.4',                         'second'),
#             (   'Association Time.5',                           'year'),
#             (               'Client',                 'Association ID'),
#             (             'Client.1',                 'Authentication'),
#             (             'Client.2',                       'EAP Type'),
#             (             'Client.3',              'Encryption Cipher'),
#             (             'Client.4',                  'Endpoint Type'),
#             (             'Client.5',                     'IP Address'),
#             (             'Client.6',                    'MAC Address'),
#             (             'Client.7',                    'Policy Type'),
#             (             'Client.8',                       'Protocol'),
#             (             'Client.9',                     'Radio Type'),
#             (            'Client.10',                           'SSID'),
#             (            'Client.11',                           'Type'),
#             (            'Client.12',                        'VLAN ID'),
#             (  'Disassociation Time',                            'day'),
#             ('Disassociation Time.1',                           'hour'),
#             ('Disassociation Time.2',                         'minute'),
#             ('Disassociation Time.3',                          'month'),
#             ('Disassociation Time.4',                         'second'),
#             ('Disassociation Time.5',                           'year'),
#             (     'Session Duration',                           'days'),
#             (   'Session Duration.1',                          'hours'),
#             (   'Session Duration.2',                        'minutes'),
#             (   'Session Duration.3',                        'seconds'),
#             (          'Utilization', 'Avg. Session Throughput (Kbps)'),
#             (        'Utilization.1',                 'Bytes Received'),
#             (        'Utilization.2',                     'Bytes Sent'),
#             (        'Utilization.3',                   'Data Retries'),
#             (        'Utilization.4',               'Packets Received'),
#             (        'Utilization.5',                   'Packets Sent'),
#             (        'Utilization.6',                     'RSSI (dBm)'),
#             (        'Utilization.7',                    'RTS Retries'),
#             (        'Utilization.8',                       'SNR (dB)')],
#            names=[None, '0'])

# %% [markdown]
# 1. 건물층, throuput, 세션시간, rssi, ssid, (휴대폰)

# %%
tempLib2 = Lib_2_df

# %%
rel = ['Client.4','AP.2','Client.10','Utilization','Utilization.6','Session Duration','Session Duration.1','Session Duration.2','Session Duration.3']
tempLib2 = tempLib2[rel]

# %%
tempLib2
# Out:
#                   Client.4                            AP.2 Client.10  \
# 0            Endpoint Type                    Map Location      SSID
# 6382081            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382082            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382083            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382084            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382085            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# ...                    ...                             ...       ...
# 6572202           iPhone X  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572203  Linux-Workstation  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572204         iPhone11,8  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572205       Unclassified  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572206       Unclassified  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
#
#                            Utilization Utilization.6 Session Duration  \
# 0       Avg. Session Throughput (Kbps)    RSSI (dBm)             days
# 6382081                            1.4           -61                0
# 6382082                            1.1           -45                0
# 6382083                           40.0           -78                0
# 6382084                            0.8           -55                0
# 6382085                            4.8           -67                0
# ...                                ...           ...              ...
# 6572202                          214.7           -53                0
# 6572203                        4,605.9           -83                0
# 6572204                           <0.1           -65                0
# 6572205                          270.5           -63                0
# 6572206                          310.4           -77                0
#
#         Session Duration.1 Session Duration.2 Session Duration.3
# 0                    hours            minutes            seconds
# 6382081                  1                 30                 26
# 6382082                  0                 20                  5
# 6382083                  1                 50                 32
# 6382084                  0                 20                  5
# 6382085                  3                 25                 59
# ...                    ...                ...                ...
# 6572202                  1                 20                 26
# 6572203                  0                 10                  3
# 6572204                  0                  5                  0
# 6572205                  2                  5                 37
# 6572206                  0                 35                 10
#
# [190126 rows x 9 columns]

# %%
tempLib2.columns
# Out:
# MultiIndex([(          'Client.4',                  'Endpoint Type'),
#             (              'AP.2',                   'Map Location'),
#             (         'Client.10',                           'SSID'),
#             (       'Utilization', 'Avg. Session Throughput (Kbps)'),
#             (     'Utilization.6',                     'RSSI (dBm)'),
#             (  'Session Duration',                           'days'),
#             ('Session Duration.1',                          'hours'),
#             ('Session Duration.2',                        'minutes'),
#             ('Session Duration.3',                        'seconds')],
#            names=[None, '0'])

# %%
totalsec = tempLib2['Session Duration']['days']*24*60*60 + tempLib2['Session Duration.1']['hours']*60*60 + tempLib2['Session Duration.2']['minutes']*60 + tempLib2['Session Duration.3']['seconds']

# %%
tempLib2.drop(['Session Duration','Session Duration.1','Session Duration.2'], axis=1, inplace=True)

# %%
tempLib2['Session Duration.3'] = totalsec

# %%
tempLib2
# Out:
#                   Client.4                            AP.2 Client.10  \
# 0            Endpoint Type                    Map Location      SSID
# 6382081            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382082            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382083            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382084            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# 6382085            Android  Pusan > Lib-2 (420) > Lib-2-1F  PNU-WiFi
# ...                    ...                             ...       ...
# 6572202           iPhone X  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572203  Linux-Workstation  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572204         iPhone11,8  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572205       Unclassified  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
# 6572206       Unclassified  Pusan > Lib-2 (420) > Lib-2-3F  PNU-WiFi
#
#                            Utilization Utilization.6 Session Duration.3
# 0       Avg. Session Throughput (Kbps)    RSSI (dBm)            seconds
# 6382081                            1.4           -61               5426
# 6382082                            1.1           -45               1205
# 6382083                           40.0           -78               6632
# 6382084                            0.8           -55               1205
# 6382085                            4.8           -67              12359
# ...                                ...           ...                ...
# 6572202                          214.7           -53               4826
# 6572203                        4,605.9           -83                603
# 6572204                           <0.1           -65                300
# 6572205                          270.5           -63               7537
# 6572206                          310.4           -77               2110
#
# [190126 rows x 6 columns]

# %%
cnt=1
for i,j in tempLib2.columns:
    if tempLib2[i][j].dtype == 'object':
        print(str(cnt) +") <" + i+" " +j,">")
        print(tempLib2[i][j].value_counts())
        print()
        cnt+=1
# Out:
# 1) <Client.4 Endpoint Type >
# Linux-Workstation               33667
# Apple-iPhone                    19756
# Android                         13802
# iPhone 7                        13337
# Android-Samsung                 13009
# Android-Samsung-Galaxy-Phone    11739
# iPhone 8                        11511
# Microsoft-Workstation            8756
# none                             8455
# iPhone11,8                       6983
# Unclassified                     6744
# Apple-iPad                       6562
# iPhone11,2                       5627
# Android-LG                       4721
# iPhone X                         4376
# iPad7,5                          4329
# Samsung-Device                   2496
# iPhone 7+                        2282
# iPhone 8+                        2038
# iPhone12,1                       1572
# iPhone11,6                       1243
# iPad11,3                         1001
# iPad Pro 2017 (10.5 inch)         883
# iPad8,1                           825
# Workstation                       801
# Apple-Device                      723
# iPhone12,3                        684
# Windows8-Workstation              328
# iPad 2017 (9.7 inch)              326
# iPad8,5                           259
# iPad7,11                          220
# OS_X-Workstation                  147
# Windows7-Workstation              126
# iPad11,4                          103
# Android-Lenovo                    103
# iPad11,2                          102
# Android-Motorola                   96
# iPad8,3                            79
# iPad Pro 2017 (12.9 inch)          73
# iPad11,1                           42
# iPad8,7                            35
# iPhone12,5                         35
# iPad7,6                            29
# Ubuntu-Workstation                 16
# Nokia-Smart-Phone                  15
# WindowsXP-Workstation              13
# Android-Sony-Ericsson              12
# Huawei-Device                       9
# OS_X_Mavericks-Workstation          7
# Android-Asus                        6
# Apple-iPod                          6
# iPhone12,8                          5
# Android-HTC                         5
# Android-Google                      4
# iPad7,12                            2
# iPad8,8                             1
# Name: Endpoint Type, dtype: int64
#
# 2) <AP.2 Map Location >
# Pusan > Lib-2 (420) > Lib-2-2F    96383
# Pusan > Lib-2 (420) > Lib-2-3F    61767
# Pusan > Lib-2 (420) > Lib-2-1F    31976
# Name: Map Location, dtype: int64
#
# 3) <Client.10 SSID >
# PNU-WiFi     154614
# eduroam       35506
# PNU-GUIDE         6
# Name: SSID, dtype: int64
#
# 4) <Utilization Avg. Session Throughput (Kbps) >
# <0.1       101034
# 0.2          2841
# 0.3          2385
# 0.4          1996
# 0.5          1711
#             ...
# 1,007.0         1
# 621.4           1
# 7,234.9         1
# 1,538.9         1
# 599.5           1
# Name: Avg. Session Throughput (Kbps), Length: 12948, dtype: int64

# %%
lib2 = tempLib2

# %%
lib2['AP.2'] = lib2['AP.2']['Map Location'].map({'Pusan > Lib-2 (420) > Lib-2-1F':1, 'Pusan > Lib-2 (420) > Lib-2-2F':2, 'Pusan > Lib-2 (420) > Lib-2-3F':3})

# %%
lib2['Utilization'] = lib2['Utilization']['Avg. Session Throughput (Kbps)'].replace(['<0.1'],['0.05'])
lib2['Utilization'] = lib2['Utilization']['Avg. Session Throughput (Kbps)'].str.replace(',', '').astype('float64')
lib2['Utilization']['Avg. Session Throughput (Kbps)'].astype('float64')
# Out:
# 6382081       1.40
# 6382082       1.10
# 6382083      40.00
# 6382084       0.80
# 6382085       4.80
#             ...
# 6572202     214.70
# 6572203    4605.90
# 6572204       0.05
# 6572205     270.50
# 6572206     310.40
# Name: Avg. Session Throughput (Kbps), Length: 190126, dtype: float64

# %%
lib2
# Out:
#                   Client.4         AP.2 Client.10  \
# 0            Endpoint Type Map Location      SSID
# 6382081            Android            1  PNU-WiFi
# 6382082            Android            1  PNU-WiFi
# 6382083            Android            1  PNU-WiFi
# 6382084            Android            1  PNU-WiFi
# 6382085            Android            1  PNU-WiFi
# ...                    ...          ...       ...
# 6572202           iPhone X            3  PNU-WiFi
# 6572203  Linux-Workstation            3  PNU-WiFi
# 6572204         iPhone11,8            3  PNU-WiFi
# 6572205       Unclassified            3  PNU-WiFi
# 6572206       Unclassified            3  PNU-WiFi
#
#                            Utilization Utilization.6 Session Duration.3
# 0       Avg. Session Throughput (Kbps)    RSSI (dBm)            seconds
# 6382081                           1.40           -61               5426
# 6382082                           1.10           -45               1205
# 6382083                          40.00           -78               6632
# 6382084                           0.80           -55               1205
# 6382085                           4.80           -67              12359
# ...                                ...           ...                ...
# 6572202                         214.70           -53               4826
# 6572203                        4605.90           -83                603
# 6572204                           0.05           -65                300
# 6572205                         270.50           -63               7537
# 6572206                         310.40           -77               2110
#
# [190126 rows x 6 columns]

# %%
set(lib2['Client.10']['SSID'])
# Out:
# {'PNU-GUIDE', 'PNU-WiFi', 'eduroam'}

# %%
lib2['Client.10'] = lib2['Client.10']['SSID'].replace(['PNU-GUIDE','PNU-WiFi', 'eduroam'],[0,1,2])

# %%
lib2['Client.10']['SSID']
# Out:
# 6382081    1
# 6382082    1
# 6382083    1
# 6382084    1
# 6382085    1
#           ..
# 6572202    1
# 6572203    1
# 6572204    1
# 6572205    1
# 6572206    1
# Name: SSID, Length: 190126, dtype: int64

# %%
lib2
# Out:
#                   Client.4         AP.2 Client.10  \
# 0            Endpoint Type Map Location      SSID
# 6382081            Android            1         1
# 6382082            Android            1         1
# 6382083            Android            1         1
# 6382084            Android            1         1
# 6382085            Android            1         1
# ...                    ...          ...       ...
# 6572202           iPhone X            3         1
# 6572203  Linux-Workstation            3         1
# 6572204         iPhone11,8            3         1
# 6572205       Unclassified            3         1
# 6572206       Unclassified            3         1
#
#                            Utilization Utilization.6 Session Duration.3
# 0       Avg. Session Throughput (Kbps)    RSSI (dBm)            seconds
# 6382081                           1.40           -61               5426
# 6382082                           1.10           -45               1205
# 6382083                          40.00           -78               6632
# 6382084                           0.80           -55               1205
# 6382085                           4.80           -67              12359
# ...                                ...           ...                ...
# 6572202                         214.70           -53               4826
# 6572203                        4605.90           -83                603
# 6572204                           0.05           -65                300
# 6572205                         270.50           -63               7537
# 6572206                         310.40           -77               2110
#
# [190126 rows x 6 columns]

# %%
com = pd.get_dummies(lib2)

# %%
com
# Out:
#          (AP.2, Map Location)  (Client.10, SSID)  \
# 6382081                     1                  1
# 6382082                     1                  1
# 6382083                     1                  1
# 6382084                     1                  1
# 6382085                     1                  1
# ...                       ...                ...
# 6572202                     3                  1
# 6572203                     3                  1
# 6572204                     3                  1
# 6572205                     3                  1
# 6572206                     3                  1
#
#          (Utilization, Avg. Session Throughput (Kbps))  \
# 6382081                                           1.40
# 6382082                                           1.10
# 6382083                                          40.00
# 6382084                                           0.80
# 6382085                                           4.80
# ...                                                ...
# 6572202                                         214.70
# 6572203                                        4605.90
# 6572204                                           0.05
# 6572205                                         270.50
# 6572206                                         310.40
#
#          (Utilization.6, RSSI (dBm))  (Session Duration.3, seconds)  \
# 6382081                          -61                           5426
# 6382082                          -45                           1205
# 6382083                          -78                           6632
# 6382084                          -55                           1205
# 6382085                          -67                          12359
# ...                              ...                            ...
# 6572202                          -53                           4826
# 6572203                          -83                            603
# 6572204                          -65                            300
# 6572205                          -63                           7537
# 6572206                          -77                           2110
#
#          ('Client.4', 'Endpoint Type')_Android  \
# 6382081                                      1
# 6382082                                      1
# 6382083                                      1
# 6382084                                      1
# 6382085                                      1
# ...                                        ...
# 6572202                                      0
# 6572203                                      0
# 6572204                                      0
# 6572205                                      0
# 6572206                                      0
#
#          ('Client.4', 'Endpoint Type')_Android-Asus  \
# 6382081                                           0
# 6382082                                           0
# 6382083                                           0
# 6382084                                           0
# 6382085                                           0
# ...                                             ...
# 6572202                                           0
# 6572203                                           0
# 6572204                                           0
# 6572205                                           0
# 6572206                                           0
#
#          ('Client.4', 'Endpoint Type')_Android-Google  \
# 6382081                                             0
# 6382082                                             0
# 6382083                                             0
# 6382084                                             0
# 6382085                                             0
# ...                                               ...
# 6572202                                             0
# 6572203                                             0
# 6572204                                             0
# 6572205                                             0
# 6572206                                             0
#
#          ('Client.4', 'Endpoint Type')_Android-HTC  \
# 6382081                                          0
# 6382082                                          0
# 6382083                                          0
# 6382084                                          0
# 6382085                                          0
# ...                                            ...
# 6572202                                          0
# 6572203                                          0
# 6572204                                          0
# 6572205                                          0
# 6572206                                          0
#
#          ('Client.4', 'Endpoint Type')_Android-LG  ...  \
# 6382081                                         0  ...
# 6382082                                         0  ...
# 6382083                                         0  ...
# 6382084                                         0  ...
# 6382085                                         0  ...
# ...                                           ...  ...
# 6572202                                         0  ...
# 6572203                                         0  ...
# 6572204                                         0  ...
# 6572205                                         0  ...
# 6572206                                         0  ...
#
#          ('Client.4', 'Endpoint Type')_iPhone 8+  \
# 6382081                                        0
# 6382082                                        0
# 6382083                                        0
# 6382084                                        0
# 6382085                                        0
# ...                                          ...
# 6572202                                        0
# 6572203                                        0
# 6572204                                        0
# 6572205                                        0
# 6572206                                        0
#
#          ('Client.4', 'Endpoint Type')_iPhone X  \
# 6382081                                       0
# 6382082                                       0
# 6382083                                       0
# 6382084                                       0
# 6382085                                       0
# ...                                         ...
# 6572202                                       1
# 6572203                                       0
# 6572204                                       0
# 6572205                                       0
# 6572206                                       0
#
#          ('Client.4', 'Endpoint Type')_iPhone11,2  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone11,6  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone11,8  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         1
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone12,1  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone12,3  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone12,5  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_iPhone12,8  \
# 6382081                                         0
# 6382082                                         0
# 6382083                                         0
# 6382084                                         0
# 6382085                                         0
# ...                                           ...
# 6572202                                         0
# 6572203                                         0
# 6572204                                         0
# 6572205                                         0
# 6572206                                         0
#
#          ('Client.4', 'Endpoint Type')_none
# 6382081                                   0
# 6382082                                   0
# 6382083                                   0
# 6382084                                   0
# 6382085                                   0
# ...                                     ...
# 6572202                                   0
# 6572203                                   0
# 6572204                                   0
# 6572205                                   0
# 6572206                                   0
#
# [190126 rows x 61 columns]

# %%
noEnd = lib2.drop(['Client.4'],axis=1)

# %%
# KMeans

# %%
X = com[:100000]

# %%
from sklearn.cluster import KMeans

# %%
# distortions = []
# for i in range(1,11):
#     km = KMeans(
#         n_clusters=i, init='random',
#         n_init=10, max_iter=300,
#         tol=1e-04, random_state=0
#     )
#     km.fit(X)
#     distortions.append(km.inertia_)
    
# plt.plot(range(1,11), distortions, marker='o')
# plt.xlabel('Number of clusters')
# plt.ylabel('Distortion')
# plt.show()

# %%
model = KMeans(n_clusters=3, init='k-means++', max_iter=100, n_init=1)
model.fit(noEnd)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=3, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
noEnd.columns[0][1]
# Out:
# 'Map Location'

# %%
model.labels_
# Out:
# array([0, 0, 2, ..., 0, 2, 0])

# %%
noEnd.columns = ['Map Location', 'SSID','Avg. Session Throughput (Kbps)','RSSI (dBm)','seconds' ]

# %%
noEnd
# Out:
#          Map Location  SSID  Avg. Session Throughput (Kbps)  RSSI (dBm)  \
# 6382081             1     1                            1.40         -61
# 6382082             1     1                            1.10         -45
# 6382083             1     1                           40.00         -78
# 6382084             1     1                            0.80         -55
# 6382085             1     1                            4.80         -67
# ...               ...   ...                             ...         ...
# 6572202             3     1                          214.70         -53
# 6572203             3     1                         4605.90         -83
# 6572204             3     1                            0.05         -65
# 6572205             3     1                          270.50         -63
# 6572206             3     1                          310.40         -77
#
#          seconds
# 6382081     5426
# 6382082     1205
# 6382083     6632
# 6382084     1205
# 6382085    12359
# ...          ...
# 6572202     4826
# 6572203      603
# 6572204      300
# 6572205     7537
# 6572206     2110
#
# [190126 rows x 5 columns]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
linked = linkage(noEnd[:10000], 'single')

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10,7))
plt.title('')
dend = shc.dendrogram(shc.linkage(noEnd[:10000], method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
result = cluster.fit_predict(noEnd[:10000])

# %%
result
# Out:
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
data = noEnd[:10000]
data['result'] = result

# %%
result
# Out:
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
data.iloc[cluster.fit_predict(data)==0,:].describe()
# Out:
#        Map Location         SSID  Avg. Session Throughput (Kbps)   RSSI (dBm)  \
# count        1445.0  1445.000000                     1445.000000  1445.000000
# mean            1.0     1.132180                      166.048374   -63.395156
# std             0.0     0.338804                      448.258858    10.656997
# min             1.0     1.000000                        0.050000  -128.000000
# 25%             1.0     1.000000                        2.100000   -68.000000
# 50%             1.0     1.000000                       22.200000   -62.000000
# 75%             1.0     1.000000                      127.700000   -57.000000
# max             1.0     2.000000                     5797.900000   -34.000000
#
#             seconds  result
# count   1445.000000  1445.0
# mean    8556.066436     0.0
# std     6027.693242     0.0
# min     3626.000000     0.0
# 25%     5130.000000     0.0
# 50%     6631.000000     0.0
# 75%     9415.000000     0.0
# max    84440.000000     0.0

# %%
data.iloc[cluster.fit_predict(data)==1,:].describe()
# Out:
#        Map Location         SSID  Avg. Session Throughput (Kbps)   RSSI (dBm)  \
# count        8554.0  8554.000000                     8554.000000  8554.000000
# mean            1.0     1.164484                      112.779676   -66.926233
# std             0.0     0.370736                      518.690340    14.108342
# min             1.0     1.000000                        0.050000  -128.000000
# 25%             1.0     1.000000                        0.050000   -72.000000
# 50%             1.0     1.000000                        1.000000   -65.000000
# 75%             1.0     1.000000                       40.575000   -59.000000
# max             1.0     2.000000                    15592.100000   -34.000000
#
#            seconds  result
# count  8554.000000  8554.0
# mean    955.044073     1.0
# std     956.141928     0.0
# min      54.000000     1.0
# 25%     301.000000     1.0
# 50%     602.000000     1.0
# 75%    1209.000000     1.0
# max    4556.000000     1.0

# %%
data.iloc[cluster.fit_predict(data)==2,:].describe()
# Out:
#        Map Location  SSID  Avg. Session Throughput (Kbps)  RSSI (dBm)  \
# count           1.0   1.0                            1.00         1.0
# mean            1.0   2.0                            0.05       -70.0
# std             NaN   NaN                             NaN         NaN
# min             1.0   2.0                            0.05       -70.0
# 25%             1.0   2.0                            0.05       -70.0
# 50%             1.0   2.0                            0.05       -70.0
# 75%             1.0   2.0                            0.05       -70.0
# max             1.0   2.0                            0.05       -70.0
#
#         seconds  result
# count       1.0     1.0
# mean   221412.0     2.0
# std         NaN     NaN
# min    221412.0     2.0
# 25%    221412.0     2.0
# 50%    221412.0     2.0
# 75%    221412.0     2.0
# max    221412.0     2.0

# %%
#dbscan

# %%
noEnd[:10000]
# Out:
#          Map Location  SSID  Avg. Session Throughput (Kbps)  RSSI (dBm)  \
# 6382081             1     1                            1.40         -61
# 6382082             1     1                            1.10         -45
# 6382083             1     1                           40.00         -78
# 6382084             1     1                            0.80         -55
# 6382085             1     1                            4.80         -67
# ...               ...   ...                             ...         ...
# 6392076             1     1                            0.70         -70
# 6392077             1     1                           85.30         -45
# 6392078             1     1                            0.05         -57
# 6392079             1     1                          238.60         -66
# 6392080             1     1                          411.80         -78
#
#          seconds
# 6382081     5426
# 6382082     1205
# 6382083     6632
# 6382084     1205
# 6382085    12359
# ...          ...
# 6392076     5439
# 6392077    31753
# 6392078      300
# 6392079     2118
# 6392080      300
#
# [10000 rows x 5 columns]

# %%
from sklearn.cluster import DBSCAN
data2 = noEnd[:10000]

model = DBSCAN(eps=0.3, min_samples=6)
predict = pd.DataFrame(model.fit_predict(data2))
predict.columns=['predict']

data2['predict'] = predict

# %%
data2['predict'] = list(predict['predict'])

# %%
data2
# Out:
#          Map Location  SSID  Avg. Session Throughput (Kbps)  RSSI (dBm)  \
# 6382081             1     1                            1.40         -61
# 6382082             1     1                            1.10         -45
# 6382083             1     1                           40.00         -78
# 6382084             1     1                            0.80         -55
# 6382085             1     1                            4.80         -67
# ...               ...   ...                             ...         ...
# 6392076             1     1                            0.70         -70
# 6392077             1     1                           85.30         -45
# 6392078             1     1                            0.05         -57
# 6392079             1     1                          238.60         -66
# 6392080             1     1                          411.80         -78
#
#          seconds  predict
# 6382081     5426       -1
# 6382082     1205       -1
# 6382083     6632       -1
# 6382084     1205       -1
# 6382085    12359       -1
# ...          ...      ...
# 6392076     5439       -1
# 6392077    31753       -1
# 6392078      300      119
# 6392079     2118       -1
# 6392080      300       -1
#
# [10000 rows x 6 columns]

# %%
# sns.pairplot(data2, hue='predict')
# plt.show()

# %%
data2.groupby(data2['predict']).describe()['RSSI (dBm)']
# Out:
#           count        mean        std    min    25%    50%    75%    max
# predict
# -1       7634.0  -64.607938  11.186365 -128.0  -70.0  -64.0  -58.0  -34.0
#  0         12.0 -128.000000   0.000000 -128.0 -128.0 -128.0 -128.0 -128.0
#  1          8.0  -79.000000   0.000000  -79.0  -79.0  -79.0  -79.0  -79.0
#  2         20.0  -58.000000   0.000000  -58.0  -58.0  -58.0  -58.0  -58.0
#  3          7.0  -52.000000   0.000000  -52.0  -52.0  -52.0  -52.0  -52.0
# ...         ...         ...        ...    ...    ...    ...    ...    ...
#  133        6.0  -58.000000   0.000000  -58.0  -58.0  -58.0  -58.0  -58.0
#  134        7.0  -62.000000   0.000000  -62.0  -62.0  -62.0  -62.0  -62.0
#  135        6.0  -57.000000   0.000000  -57.0  -57.0  -57.0  -57.0  -57.0
#  136        8.0  -63.000000   0.000000  -63.0  -63.0  -63.0  -63.0  -63.0
#  137        9.0  -72.000000   0.000000  -72.0  -72.0  -72.0  -72.0  -72.0
#
# [139 rows x 8 columns]

# %%
data2.groupby(data2['predict']).describe()['Avg. Session Throughput (Kbps)']
# Out:
#           count        mean           std   min   25%    50%       75%  \
# predict
# -1       7634.0  157.777109  5.779761e+02  0.05  0.60  9.700  100.5750
#  0         12.0    0.050000  7.247438e-18  0.05  0.05  0.050    0.0500
#  1          8.0    0.050000  7.417990e-18  0.05  0.05  0.050    0.0500
#  2         20.0    0.057500  3.354102e-02  0.05  0.05  0.050    0.0500
#  3          7.0    0.050000  7.494862e-18  0.05  0.05  0.050    0.0500
# ...         ...         ...           ...   ...   ...    ...       ...
#  133        6.0    0.175000  1.753568e-01  0.05  0.05  0.125    0.2000
#  134        7.0    0.057143  1.889822e-02  0.05  0.05  0.050    0.0500
#  135        6.0    0.050000  7.601177e-18  0.05  0.05  0.050    0.0500
#  136        8.0    0.125000  1.414214e-01  0.05  0.05  0.050    0.1125
#  137        9.0    0.050000  7.359808e-18  0.05  0.05  0.050    0.0500
#
#               max
# predict
# -1       15592.10
#  0           0.05
#  1           0.05
#  2           0.20
#  3           0.05
# ...           ...
#  133         0.50
#  134         0.10
#  135         0.05
#  136         0.40
#  137         0.05
#
# [139 rows x 8 columns]

# %%
data2.groupby(data2['predict']).describe()['seconds']
# Out:
#           count         mean          std    min    25%     50%     75%  \
# predict
# -1       7634.0  2614.782814  4724.952689   54.0  303.0  1205.0  3025.0
#  0         12.0   301.000000     0.000000  301.0  301.0   301.0   301.0
#  1          8.0   301.000000     0.000000  301.0  301.0   301.0   301.0
#  2         20.0   301.000000     0.000000  301.0  301.0   301.0   301.0
#  3          7.0   602.000000     0.000000  602.0  602.0   602.0   602.0
# ...         ...          ...          ...    ...    ...     ...     ...
#  133        6.0   604.000000     0.000000  604.0  604.0   604.0   604.0
#  134        7.0   302.000000     0.000000  302.0  302.0   302.0   302.0
#  135        6.0   302.000000     0.000000  302.0  302.0   302.0   302.0
#  136        8.0   302.000000     0.000000  302.0  302.0   302.0   302.0
#  137        9.0   302.000000     0.000000  302.0  302.0   302.0   302.0
#
#               max
# predict
# -1       221412.0
#  0          301.0
#  1          301.0
#  2          301.0
#  3          602.0
# ...           ...
#  133        604.0
#  134        302.0
#  135        302.0
#  136        302.0
#  137        302.0
#
# [139 rows x 8 columns]
